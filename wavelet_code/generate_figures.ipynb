# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
gdf = gpd.read_file("data/shapefiles/SpCenterCensus5k.geojson")
selected =[375, 408, 456, 495]
gdf = gdf[gdf.id_poly.isin(selected)]

# %%
gdf.plot(color = "#e5d8bd", edgecolor = "#999999")
plt.axis("off")

plt.savefig("poly.svg", dpi = 300)
