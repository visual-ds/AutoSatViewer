# %%
import pandas as pd
# Out:
# /tmp/ipykernel_89837/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
day_range = ["2019-12-01", "2020-02-01"]
df = pd.read_csv("data/time_series/waze-alerts.csv")
df = df[df[" type"] == "ROAD_CLOSED"]
#df = df[["geo", "ts", " type"]]
df = df.rename(columns = {" type" : "type"})
df["date"] = pd.to_datetime(df["ts"])
df = df[df.date >= day_range[0]]
df = df[df.date < day_range[1]]
df["LONGITUDE"] = df["geo"].apply(lambda x : x.split("(")[1].split(" ")[0])
df["LATITUDE"] = df["geo"].apply(lambda x : x.split(" ")[1].split(")")[0])
df.LONGITUDE = df.LONGITUDE.astype(float)
df.LATITUDE = df.LATITUDE.astype(float)
df["type"] = df["type"].apply(lambda x : "ROADCLOSED" if x == "ROAD_CLOSED" else x)
df = df[df.date >= day_range[0]]
df = df[df.date < day_range[1]]

# %%
df
# Out:
#                                    geo                       ts        type  \
# 1087       POINT(-46.61388 -23.533371)  2020-01-18 18:18:49 UTC  ROADCLOSED
# 1301      POINT(-46.591951 -23.595279)  2020-01-25 15:51:05 UTC  ROADCLOSED
# 3147      POINT(-46.649394 -23.556591)  2020-01-26 20:16:57 UTC  ROADCLOSED
# 3862       POINT(-46.66422 -23.605613)  2019-12-01 21:25:59 UTC  ROADCLOSED
# 5492      POINT(-46.702596 -23.623101)  2019-12-01 12:27:20 UTC  ROADCLOSED
# ...                                ...                      ...         ...
# 44869607  POINT(-46.655763 -23.561959)  2019-12-25 17:12:32 UTC  ROADCLOSED
# 44869873  POINT(-46.658553 -23.558702)  2020-01-25 01:28:06 UTC  ROADCLOSED
# 44869876  POINT(-46.699857 -23.588475)  2019-12-28 07:35:59 UTC  ROADCLOSED
# 44905317  POINT(-46.658247 -23.556241)  2019-12-29 21:29:57 UTC  ROADCLOSED
# 44905324  POINT(-46.558594 -23.506034)  2020-01-12 15:27:59 UTC  ROADCLOSED
#
#                     subtype   reliability   confidence  \
# 1087                    NaN             5            0
# 1301                    NaN             5            0
# 3147                    NaN             5            0
# 3862                    NaN             5            0
# 5492                    NaN             5            0
# ...                     ...           ...          ...
# 44869607  ROAD_CLOSED_EVENT             6            0
# 44869873  ROAD_CLOSED_EVENT             6            0
# 44869876  ROAD_CLOSED_EVENT             6            0
# 44905317  ROAD_CLOSED_EVENT             7            0
# 44905324  ROAD_CLOSED_EVENT             7            0
#
#                               date  LONGITUDE   LATITUDE
# 1087     2020-01-18 18:18:49+00:00 -46.613880 -23.533371
# 1301     2020-01-25 15:51:05+00:00 -46.591951 -23.595279
# 3147     2020-01-26 20:16:57+00:00 -46.649394 -23.556591
# 3862     2019-12-01 21:25:59+00:00 -46.664220 -23.605613
# 5492     2019-12-01 12:27:20+00:00 -46.702596 -23.623101
# ...                            ...        ...        ...
# 44869607 2019-12-25 17:12:32+00:00 -46.655763 -23.561959
# 44869873 2020-01-25 01:28:06+00:00 -46.658553 -23.558702
# 44869876 2019-12-28 07:35:59+00:00 -46.699857 -23.588475
# 44905317 2019-12-29 21:29:57+00:00 -46.658247 -23.556241
# 44905324 2020-01-12 15:27:59+00:00 -46.558594 -23.506034
#
# [11131 rows x 9 columns]
